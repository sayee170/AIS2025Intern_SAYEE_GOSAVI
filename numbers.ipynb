# %% [markdown]
# # NUMBERS

# %% [markdown]
# * Addition

# %%
a = 10
b = 5.5
c = 4*4
d = 15
e = 2

print ("Addition ",a+b)
# Out:
# Addition  15.5

# %% [markdown]
# * Subtraction

# %%
a = 10
b = 5.5
c = 4*4
d = 15
e = 2

print ("Subtraction ",d-a)
# Out:
# Subtraction  5

# %% [markdown]
# * Multiplication

# %%
a = 10
b = 5.5
c = 4*4
d = 15
e = 2

print ("Multiplication ",d*e)
# Out:
# Multiplication  30

# %% [markdown]
# * Division

# %%
a = 10
b = 5.5
c = 4*4
d = 15
e = 2

print ("Division ",c/d)
# Out:
# Division  1.0666666666666667

# %% [markdown]
# * Modulus

# %%
a = 10
b = 5.5
c = 4*4
d = 15
e = 2

print ("Modulus ",a%c)
# Out:
# Modulus  10
