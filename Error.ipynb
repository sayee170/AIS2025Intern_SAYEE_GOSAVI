# %% [markdown]
# # ERRORS

# %%
if x > 5:
print("x is greater than 5") # identation error
# Out:
#   Cell In[1], line 2
#     print("x is greater than 5") # identation error
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
my_variable = 10
print(my_varible) # name error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 my_variable = 10
# ----> 2 print(my_varible)
#
# NameError: name 'my_varible' is not defined

# %%
my_list = [1, 2, 3]
   my_list[5]  # value error
# Out:
#   Cell In[7], line 2
#     my_list[5]  # value error
#     ^
# IndentationError: unexpected indent

# %%
#  type errror 
print("1" + 2  )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #  type errror
# ----> 2 print("1" + 2  )
#
# TypeError: can only concatenate str (not "int") to str

# %%
my_list = [1, 2, 3]  # index error 
print(my_list[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 my_list = [1, 2, 3]  # index error
# ----> 2 print(my_list[3])
#
# IndexError: list index out of range

# %%
#keyerror 
my_dict = {'name': 'Sayee', 'age':21 }
print(my_dict['city'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 #keyerror
#       2 my_dict = {'name': 'Sayee', 'age':21 }
# ----> 3 print(my_dict['city'])
#
# KeyError: 'city'
