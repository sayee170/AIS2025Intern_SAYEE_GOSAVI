# %% [markdown]
# # TUPLES

# %%
print("Operation of tuples")

abc=(1,2,3,4,5)
print(abc)
# Out:
# Operation of tuples
# (1, 2, 3, 4, 5)

# %%
print("     TUPLES         ")
t=(1,2,3,4,5)
print(t[1])#using index
a=t[0:3]#slicing 
print(a)
b=(10,20,30)#new tuple
c=t+b # concatention
print(c)
c=c*2 # repetition
print(c)
d=c.count(2)
print(d)
e=c.index(10)
print(e)
# Out:
#      TUPLES
# 2
# (1, 2, 3)
# (1, 2, 3, 4, 5, 10, 20, 30)
# (1, 2, 3, 4, 5, 10, 20, 30, 1, 2, 3, 4, 5, 10, 20, 30)
# 2
# 5
